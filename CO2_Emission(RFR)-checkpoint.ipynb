# %%
import numpy as np
import pandas as pd
from matplotlib.pyplot import *

# %%
dataset=pd.read_csv('Emission_Co2.csv')
dataset
# Out:
#       MODELYEAR          MAKE                        MODEL    VEHICLECLASS  \
# 0          2014         ACURA                          ILX         COMPACT
# 1          2014         ACURA                          ILX         COMPACT
# 2          2014         ACURA                   ILX HYBRID         COMPACT
# 3          2014         ACURA                      MDX 4WD     SUV - SMALL
# 4          2014         ACURA                      RDX AWD     SUV - SMALL
# 5          2014         ACURA                          RLX        MID-SIZE
# 6          2014         ACURA                           TL        MID-SIZE
# 7          2014         ACURA                       TL AWD        MID-SIZE
# 8          2014         ACURA                       TL AWD        MID-SIZE
# 9          2014         ACURA                          TSX         COMPACT
# 10         2014         ACURA                          TSX         COMPACT
# 11         2014         ACURA                          TSX         COMPACT
# 12         2014  ASTON MARTIN                          DB9     MINICOMPACT
# 13         2014  ASTON MARTIN                       RAPIDE      SUBCOMPACT
# 14         2014  ASTON MARTIN                   V8 VANTAGE      TWO-SEATER
# 15         2014  ASTON MARTIN                   V8 VANTAGE      TWO-SEATER
# 16         2014  ASTON MARTIN                 V8 VANTAGE S      TWO-SEATER
# 17         2014  ASTON MARTIN                 V8 VANTAGE S      TWO-SEATER
# 18         2014  ASTON MARTIN                     VANQUISH     MINICOMPACT
# 19         2014          AUDI                           A4         COMPACT
# 20         2014          AUDI                   A4 QUATTRO         COMPACT
# 21         2014          AUDI                   A4 QUATTRO         COMPACT
# 22         2014          AUDI         A5 CABRIOLET QUATTRO      SUBCOMPACT
# 23         2014          AUDI                   A5 QUATTRO      SUBCOMPACT
# 24         2014          AUDI                   A5 QUATTRO      SUBCOMPACT
# 25         2014          AUDI                   A6 QUATTRO        MID-SIZE
# 26         2014          AUDI                   A6 QUATTRO        MID-SIZE
# 27         2014          AUDI  A6 QUATTRO TDI CLEAN DIESEL        MID-SIZE
# 28         2014          AUDI                   A7 QUATTRO        MID-SIZE
# 29         2014          AUDI  A7 QUATTRO TDI CLEAN DIESEL        MID-SIZE
# ...         ...           ...                          ...             ...
# 1037       2014    VOLKSWAGEN                        JETTA         COMPACT
# 1038       2014    VOLKSWAGEN                    JETTA GLI         COMPACT
# 1039       2014    VOLKSWAGEN                    JETTA GLI         COMPACT
# 1040       2014    VOLKSWAGEN       JETTA TDI CLEAN DIESEL         COMPACT
# 1041       2014    VOLKSWAGEN       JETTA TDI CLEAN DIESEL         COMPACT
# 1042       2014    VOLKSWAGEN           JETTA TURBO HYBRID         COMPACT
# 1043       2014    VOLKSWAGEN                       PASSAT        MID-SIZE
# 1044       2014    VOLKSWAGEN                       PASSAT        MID-SIZE
# 1045       2014    VOLKSWAGEN                       PASSAT        MID-SIZE
# 1046       2014    VOLKSWAGEN                       PASSAT        MID-SIZE
# 1047       2014    VOLKSWAGEN                       PASSAT        MID-SIZE
# 1048       2014    VOLKSWAGEN      PASSAT TDI CLEAN DIESEL        MID-SIZE
# 1049       2014    VOLKSWAGEN      PASSAT TDI CLEAN DIESEL        MID-SIZE
# 1050       2014    VOLKSWAGEN                       ROUTAN         MINIVAN
# 1051       2014    VOLKSWAGEN                       TIGUAN     SUV - SMALL
# 1052       2014    VOLKSWAGEN                       TIGUAN     SUV - SMALL
# 1053       2014    VOLKSWAGEN               TIGUAN 4MOTION     SUV - SMALL
# 1054       2014    VOLKSWAGEN                      TOUAREG  SUV - STANDARD
# 1055       2014    VOLKSWAGEN     TOUAREG TDI CLEAN DIESEL  SUV - STANDARD
# 1056       2014         VOLVO                          S60         COMPACT
# 1057       2014         VOLVO                      S60 AWD         COMPACT
# 1058       2014         VOLVO                      S60 AWD         COMPACT
# 1059       2014         VOLVO                          S80        MID-SIZE
# 1060       2014         VOLVO                      S80 AWD        MID-SIZE
# 1061       2014         VOLVO                         XC60     SUV - SMALL
# 1062       2014         VOLVO                     XC60 AWD     SUV - SMALL
# 1063       2014         VOLVO                     XC60 AWD     SUV - SMALL
# 1064       2014         VOLVO                     XC70 AWD     SUV - SMALL
# 1065       2014         VOLVO                     XC70 AWD     SUV - SMALL
# 1066       2014         VOLVO                     XC90 AWD  SUV - STANDARD
#
#      FUELTYPE  CYLINDERS  ENGINESIZE  FUELCONSUMPTION_HWY  \
# 0           Z          4         2.0                  6.7
# 1           Z          4         2.4                  7.7
# 2           Z          4         1.5                  5.8
# 3           Z          6         3.5                  9.1
# 4           Z          6         3.5                  8.7
# 5           Z          6         3.5                  7.7
# 6           Z          6         3.5                  8.1
# 7           Z          6         3.7                  9.0
# 8           Z          6         3.7                  9.5
# 9           Z          4         2.4                  7.5
# 10          Z          4         2.4                  8.1
# 11          Z          6         3.5                  8.3
# 12          Z         12         5.9                 12.6
# 13          Z         12         5.9                 12.6
# 14          Z          8         4.7                 11.3
# 15          Z          8         4.7                 12.2
# 16          Z          8         4.7                 11.3
# 17          Z          8         4.7                 12.2
# 18          Z         12         5.9                 12.6
# 19          Z          4         2.0                  7.4
# 20          Z          4         2.0                  8.1
# 21          Z          4         2.0                  7.5
# 22          Z          4         2.0                  8.1
# 23          Z          4         2.0                  8.1
# 24          Z          4         2.0                  7.5
# 25          Z          4         2.0                  8.1
# 26          Z          6         3.0                  8.6
# 27          Z          6         3.0                  6.4
# 28          Z          6         3.0                  8.8
# 29          Z          6         3.0                  6.4
# ...       ...        ...         ...                  ...
# 1037        X          4         2.0                  7.2
# 1038        Z          4         2.0                  7.5
# 1039        Z          4         2.0                  7.4
# 1040        X          4         2.0                  5.7
# 1041        X          4         2.0                  5.6
# 1042        Z          4         1.4                  5.2
# 1043        X          4         1.8                  6.9
# 1044        X          4         1.8                  6.9
# 1045        X          5         2.5                  8.0
# 1046        X          5         2.5                  7.8
# 1047        Z          6         3.6                  8.8
# 1048        X          4         2.0                  5.9
# 1049        X          4         2.0                  5.4
# 1050        X          6         3.6                  9.5
# 1051        Z          4         2.0                  9.5
# 1052        Z          4         2.0                  9.2
# 1053        Z          4         2.0                  9.4
# 1054        Z          6         3.6                 10.3
# 1055        X          6         3.0                  8.0
# 1056        X          5         2.5                  7.8
# 1057        X          5         2.5                  8.3
# 1058        X          6         3.0                  9.5
# 1059        X          6         3.2                  8.1
# 1060        X          6         3.0                  9.5
# 1061        X          6         3.2                  8.9
# 1062        X          6         3.0                  9.8
# 1063        X          6         3.2                  9.5
# 1064        X          6         3.0                  9.8
# 1065        X          6         3.2                  9.3
# 1066        X          6         3.2                 10.2
#
#       FUELCONSUMPTION_CITY  FUELCONSUMPTION_COMB  CO2EMISSIONS
# 0                      9.9                   8.5           196
# 1                     11.2                   9.6           221
# 2                      6.0                   5.9           136
# 3                     12.7                  11.1           255
# 4                     12.1                  10.6           244
# 5                     11.9                  10.0           230
# 6                     11.8                  10.1           232
# 7                     12.8                  11.1           255
# 8                     13.4                  11.6           267
# 9                     10.6                   9.2           212
# 10                    11.2                   9.8           225
# 11                    12.1                  10.4           239
# 12                    18.0                  15.6           359
# 13                    18.0                  15.6           359
# 14                    17.4                  14.7           338
# 15                    18.1                  15.4           354
# 16                    17.4                  14.7           338
# 17                    18.1                  15.4           354
# 18                    18.0                  15.6           359
# 19                     9.9                   8.8           202
# 20                    11.5                  10.0           230
# 21                    10.8                   9.3           214
# 22                    11.5                  10.0           230
# 23                    11.5                  10.0           230
# 24                    10.8                   9.3           214
# 25                    12.0                  10.2           235
# 26                    12.8                  10.9           251
# 27                     9.8                   8.3           224
# 28                    13.1                  11.2           258
# 29                     9.8                   8.3           224
# ...                    ...                   ...           ...
# 1037                  10.4                   9.0           207
# 1038                  10.2                   9.0           207
# 1039                  10.6                   9.2           212
# 1040                   7.9                   6.9           186
# 1041                   7.9                   6.9           186
# 1042                   5.6                   5.4           124
# 1043                   9.9                   8.6           198
# 1044                  10.0                   8.6           198
# 1045                  11.0                   9.7           223
# 1046                  11.4                   9.8           225
# 1047                  12.4                  10.8           248
# 1048                   8.1                   7.1           192
# 1049                   8.0                   6.8           184
# 1050                  14.2                  12.1           278
# 1051                  11.7                  10.7           246
# 1052                  13.6                  11.6           267
# 1053                  11.7                  10.7           246
# 1054                  13.8                  12.2           281
# 1055                  12.3                  10.4           281
# 1056                  11.3                   9.7           223
# 1057                  11.6                  10.1           232
# 1058                  13.2                  11.5           264
# 1059                  11.9                  10.2           235
# 1060                  13.2                  11.5           264
# 1061                  13.0                  11.2           258
# 1062                  13.4                  11.8           271
# 1063                  13.2                  11.5           264
# 1064                  13.4                  11.8           271
# 1065                  12.9                  11.3           260
# 1066                  14.9                  12.8           294
#
# [1067 rows x 11 columns]

# %%
dataset.isnull().any()
# Out:
# MODELYEAR               False
# MAKE                    False
# MODEL                   False
# VEHICLECLASS            False
# FUELTYPE                False
# CYLINDERS               False
# ENGINESIZE              False
# FUELCONSUMPTION_HWY     False
# FUELCONSUMPTION_CITY    False
# FUELCONSUMPTION_COMB    False
# CO2EMISSIONS            False
# dtype: bool

# %%
dataset.corr()
# Out:
#                       MODELYEAR  CYLINDERS  ENGINESIZE  FUELCONSUMPTION_HWY  \
# MODELYEAR                   NaN        NaN         NaN                  NaN
# CYLINDERS                   NaN   1.000000    0.934011             0.724594
# ENGINESIZE                  NaN   0.934011    1.000000             0.778746
# FUELCONSUMPTION_HWY         NaN   0.724594    0.778746             1.000000
# FUELCONSUMPTION_CITY        NaN   0.796473    0.832225             0.965718
# FUELCONSUMPTION_COMB        NaN   0.776788    0.819482             0.985804
# CO2EMISSIONS                NaN   0.849685    0.874154             0.861748
#
#                       FUELCONSUMPTION_CITY  FUELCONSUMPTION_COMB  CO2EMISSIONS
# MODELYEAR                              NaN                   NaN           NaN
# CYLINDERS                         0.796473              0.776788      0.849685
# ENGINESIZE                        0.832225              0.819482      0.874154
# FUELCONSUMPTION_HWY               0.965718              0.985804      0.861748
# FUELCONSUMPTION_CITY              1.000000              0.995542      0.898039
# FUELCONSUMPTION_COMB              0.995542              1.000000      0.892129
# CO2EMISSIONS                      0.898039              0.892129      1.000000

# %%
x = dataset.iloc[:,5:10].values
x
# Out:
# array([[ 4. ,  2. ,  6.7,  9.9,  8.5],
#        [ 4. ,  2.4,  7.7, 11.2,  9.6],
#        [ 4. ,  1.5,  5.8,  6. ,  5.9],
#        ...,
#        [ 6. ,  3. ,  9.8, 13.4, 11.8],
#        [ 6. ,  3.2,  9.3, 12.9, 11.3],
#        [ 6. ,  3.2, 10.2, 14.9, 12.8]])

# %%
y = dataset.iloc[:,-1::].values
y
# Out:
# array([[196],
#        [221],
#        [136],
#        ...,
#        [271],
#        [260],
#        [294]], dtype=int64)

# %%
import seaborn as sns
sns.heatmap(dataset.corr(),annot=True)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=10)

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators=20, random_state=10,max_depth =10)
regressor.fit(x_train, y_train)
y_predict = regressor.predict(x_test)
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
from sklearn.metrics import r2_score
acc = r2_score(y_test,y_predict)
acc
# Out:
# 0.9691783308406884
